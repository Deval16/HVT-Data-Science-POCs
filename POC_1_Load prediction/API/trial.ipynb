# %%
import pandas as pd

import numpy as np


df = pd.DataFrame({

    'Employee_ID': [101, 102, 103, 104, 105, 106, 107, 108],

    'Name': ['John', 'Alice', None, 'David', 'Emma', 'Ryan', 'Sophia', None],

    'Department': ['IT', 'HR', 'IT', None, 'Finance', 'HR', 'IT', 'Finance'],

    'Age': [25, np.nan, 30, 28, np.nan, 35, 29, 31],

    'Salary': [60000, 55000, np.nan, 75000, 80000, np.nan, 70000, 65000],

    'Experience': [2, 5, np.nan, 4, 6, 8, np.nan, 3],

    'Gender': ['M', 'F', None, 'M', 'F', 'M', 'F', None],

    'Performance_Rating': [4, 3, 5, np.nan, 4, 5, 3, np.nan]

})

# %%
# print(df)
#1. Get employees whose Age > 28 and Salary > 60000
 
answer=df[(df["Age"]>28) & 
(df["Salary"]>60000)]

print(answer['Name'])
# Out:
# 6    Sophia
# 7       NaN
# Name: Name, dtype: str

# %%
print(df)
# Out:
#    Employee_ID    Name Department   Age   Salary  Experience Gender  \
# 0          101    John         IT  25.0  60000.0         2.0      M
# 1          102   Alice         HR   NaN  55000.0         5.0      F
# 2          103     NaN         IT  30.0      NaN         NaN    NaN
# 3          104   David        NaN  28.0  75000.0         4.0      M
# 4          105    Emma    Finance   NaN  80000.0         6.0      F
# 5          106    Ryan         HR  35.0      NaN         8.0      M
# 6          107  Sophia         IT  29.0  70000.0         NaN      F
# 7          108     NaN    Finance  31.0  65000.0         3.0    NaN
#
#    Performance_Rating
# 0                 4.0
# 1                 3.0
# 2                 5.0
# 3                 NaN
# 4                 4.0
# 5                 5.0
# 6                 3.0
# 7                 NaN
